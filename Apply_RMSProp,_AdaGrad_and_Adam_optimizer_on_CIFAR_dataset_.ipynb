# %% [markdown]
# ## Imports

# %%
from __future__ import print_function

import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16.0, 9.0)
import numpy as np

# Seed
np.random.seed(1)

# %% [markdown]
# ## Load Data

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 15s 0us/step

# %% [markdown]
# ### Visualize shapes

# %%
print('X_Train:\t', X_train.shape)
print('y_train:\t', y_train.shape)

print('X_test:\t\t', X_test.shape)
print('y_test:\t\t', y_test.shape)

input_shape = X_train[0].shape
print('\nInput Shape:\t', input_shape)
# Out:
# X_Train:	 (50000, 32, 32, 3)
# y_train:	 (50000, 1)
# X_test:		 (10000, 32, 32, 3)
# y_test:		 (10000, 1)
#
# Input Shape:	 (32, 32, 3)

# %% [markdown]
# ### Print random samples

# %%
for i in np.random.randint(0, X_train.shape[0], 5):
    print('\n', y_train[i])
    plt.imshow(X_train[i])
    plt.show()
# Out:
#  [0]
#  [8]
#  [3]
#  [5]
#  [7]

# %% [markdown]
# ### Scaling of Data

# %%
# Scaling

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')


X_train /= 255
X_test /= 255

# %% [markdown]
# ### Check image consistency after scaling

# %%
# Consistency check

for i in np.random.randint(0, X_train.shape[0], 10):
    print('\n', y_train[i])
    plt.imshow(X_train[i])
    plt.show()
# Out:
#  [7]
#  [0]
#  [5]
#  [6]
#  [0]
#  [4]
#  [0]
#  [6]
#  [3]
#  [0]

# %% [markdown]
# ## Define Model

# %%
def get_model():

    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', input_shape=input_shape, activation='relu'))
    model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
    model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    model.add(Dense(units=512, activation='relu'))
    model.add(Dense(units=128, activation='relu'))
    model.add(Dense(units=32, activation='relu'))
    model.add(Dense(units=10, activation='relu'))

    model.add(Dense(units=10, activation='softmax'))

    print('Model initialized. Please compile before training.')

    return model

# %% [markdown]
# ### Set basic hyperparameters

# %%
# Hyperparameters

batch_size = 128
epochs = 10

# %%
model_sgd_plain = get_model()
# Out:
# Model initialized. Please compile before training.

# %%
model_sgd_plain.summary()
sgd_plain = keras.optimizers.SGD()
model_sgd_plain.compile(loss='sparse_categorical_crossentropy', optimizer=sgd_plain, metrics=['accuracy'])
history_sgd_plain = model_sgd_plain.fit(X_train, y_train, batch_size=batch_size,
                              epochs=epochs, validation_data=(X_test, y_test), shuffle=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 512)               819712
#
#  dense_1 (Dense)             (None, 128)               65664
#
#  dense_2 (Dense)             (None, 32)                4128
#
#  dense_3 (Dense)             (None, 10)                330
#
#  dense_4 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 955,512
# Trainable params: 955,512
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 12s 12ms/step - loss: 2.3004 - accuracy: 0.1288 - val_loss: 2.2964 - val_accuracy: 0.1608
# Epoch 2/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.2884 - accuracy: 0.1487 - val_loss: 2.2728 - val_accuracy: 0.1603
# Epoch 3/10
# 391/391 [==============================] - 4s 10ms/step - loss: 2.2450 - accuracy: 0.1881 - val_loss: 2.1846 - val_accuracy: 0.2287
# Epoch 4/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.1417 - accuracy: 0.2352 - val_loss: 2.0706 - val_accuracy: 0.2659
# Epoch 5/10
# 391/391 [==============================] - 4s 10ms/step - loss: 2.0373 - accuracy: 0.2677 - val_loss: 2.0216 - val_accuracy: 0.2649
# Epoch 6/10
# 391/391 [==============================] - 5s 12ms/step - loss: 1.9511 - accuracy: 0.3014 - val_loss: 1.9435 - val_accuracy: 0.2887
# Epoch 7/10
# 391/391 [==============================] - 4s 11ms/step - loss: 1.8616 - accuracy: 0.3278 - val_loss: 1.7721 - val_accuracy: 0.3536
# Epoch 8/10
# 391/391 [==============================] - 4s 10ms/step - loss: 1.7558 - accuracy: 0.3647 - val_loss: 1.7014 - val_accuracy: 0.3702
# Epoch 9/10
# 391/391 [==============================] - 4s 11ms/step - loss: 1.6746 - accuracy: 0.3936 - val_loss: 1.7329 - val_accuracy: 0.3853
# Epoch 10/10
# 391/391 [==============================] - 4s 11ms/step - loss: 1.6033 - accuracy: 0.4179 - val_loss: 1.5767 - val_accuracy: 0.4293

# %%
model_sgd_plain.save('model_sgd_plain.h5')

# %%
model_adam = get_model()
# Out:
# Model initialized. Please compile before training.

# %%
model_adam.summary()
adam = keras.optimizers.Adam()
model_adam.compile(loss='sparse_categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
history_adam = model_adam.fit(X_train, y_train, batch_size=batch_size,
                              epochs=epochs, validation_data=(X_test, y_test), shuffle=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 32, 32, 32)        896
#
#  conv2d_5 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 13, 13, 64)        18496
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dense_5 (Dense)             (None, 512)               819712
#
#  dense_6 (Dense)             (None, 128)               65664
#
#  dense_7 (Dense)             (None, 32)                4128
#
#  dense_8 (Dense)             (None, 10)                330
#
#  dense_9 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 955,512
# Trainable params: 955,512
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 6s 13ms/step - loss: 1.8570 - accuracy: 0.3167 - val_loss: 1.4893 - val_accuracy: 0.4497
# Epoch 2/10
# 391/391 [==============================] - 4s 11ms/step - loss: 1.3460 - accuracy: 0.5118 - val_loss: 1.2402 - val_accuracy: 0.5626
# Epoch 3/10
# 391/391 [==============================] - 4s 11ms/step - loss: 1.1081 - accuracy: 0.6035 - val_loss: 1.1244 - val_accuracy: 0.6002
# Epoch 4/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.9324 - accuracy: 0.6674 - val_loss: 0.9590 - val_accuracy: 0.6684
# Epoch 5/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.8102 - accuracy: 0.7115 - val_loss: 0.8905 - val_accuracy: 0.6907
# Epoch 6/10
# 391/391 [==============================] - 5s 12ms/step - loss: 0.7023 - accuracy: 0.7520 - val_loss: 0.8529 - val_accuracy: 0.7091
# Epoch 7/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.6239 - accuracy: 0.7788 - val_loss: 0.8284 - val_accuracy: 0.7196
# Epoch 8/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.5282 - accuracy: 0.8112 - val_loss: 0.8280 - val_accuracy: 0.7301
# Epoch 9/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.4516 - accuracy: 0.8410 - val_loss: 0.8751 - val_accuracy: 0.7313
# Epoch 10/10
# 391/391 [==============================] - 4s 11ms/step - loss: 0.3759 - accuracy: 0.8671 - val_loss: 0.9250 - val_accuracy: 0.7269

# %%
model_adam.save('model_adam.h5')

# %%
model_rms = get_model()
# Out:
# Model initialized. Please compile before training.

# %%
model_rms.summary()
rmsprop = keras.optimizers.RMSprop()
model_rms.compile(loss='sparse_categorical_crossentropy', optimizer=rmsprop, metrics=['accuracy'])
history_rmsprop = model_rms.fit(X_train, y_train, batch_size=batch_size,
                              epochs=epochs, validation_data=(X_test, y_test), shuffle=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 32, 32, 32)        896
#
#  conv2d_9 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d_4 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 13, 13, 64)        18496
#
#  conv2d_11 (Conv2D)          (None, 11, 11, 64)        36928
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 1600)              0
#
#  dense_10 (Dense)            (None, 512)               819712
#
#  dense_11 (Dense)            (None, 128)               65664
#
#  dense_12 (Dense)            (None, 32)                4128
#
#  dense_13 (Dense)            (None, 10)                330
#
#  dense_14 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 955,512
# Trainable params: 955,512
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 6s 13ms/step - loss: 2.3029 - accuracy: 0.0968 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.3027 - accuracy: 0.0963 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.3027 - accuracy: 0.0990 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 4/10
# 391/391 [==============================] - 5s 12ms/step - loss: 2.3027 - accuracy: 0.0987 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 5/10
# 391/391 [==============================] - 5s 12ms/step - loss: 2.3027 - accuracy: 0.0986 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 6/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.3027 - accuracy: 0.0989 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 7/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.3027 - accuracy: 0.0984 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 8/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.3027 - accuracy: 0.0974 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 9/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.3027 - accuracy: 0.0988 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 10/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.3027 - accuracy: 0.0969 - val_loss: 2.3026 - val_accuracy: 0.1000

# %%
model_rms.save('model_rms.h5')

# %%
model_adagrad = get_model()
# Out:
# Model initialized. Please compile before training.

# %%
model_adagrad.summary()
adagrad = keras.optimizers.Adagrad()
model_adagrad.compile(loss='sparse_categorical_crossentropy', optimizer=adagrad, metrics=['accuracy'])
history_adagrad= model_adagrad.fit(X_train, y_train, batch_size=batch_size,
                              epochs=epochs, validation_data=(X_test, y_test), shuffle=True)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 32, 32, 32)        896
#
#  conv2d_13 (Conv2D)          (None, 30, 30, 32)        9248
#
#  max_pooling2d_6 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 13, 13, 64)        18496
#
#  conv2d_15 (Conv2D)          (None, 11, 11, 64)        36928
#
#  max_pooling2d_7 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 1600)              0
#
#  dense_15 (Dense)            (None, 512)               819712
#
#  dense_16 (Dense)            (None, 128)               65664
#
#  dense_17 (Dense)            (None, 32)                4128
#
#  dense_18 (Dense)            (None, 10)                330
#
#  dense_19 (Dense)            (None, 10)                110
#
# =================================================================
# Total params: 955,512
# Trainable params: 955,512
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 5s 11ms/step - loss: 2.3019 - accuracy: 0.1045 - val_loss: 2.3008 - val_accuracy: 0.1180
# Epoch 2/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.2999 - accuracy: 0.1304 - val_loss: 2.2988 - val_accuracy: 0.1404
# Epoch 3/10
# 391/391 [==============================] - 5s 12ms/step - loss: 2.2975 - accuracy: 0.1380 - val_loss: 2.2958 - val_accuracy: 0.1566
# Epoch 4/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.2936 - accuracy: 0.1515 - val_loss: 2.2900 - val_accuracy: 0.1497
# Epoch 5/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.2838 - accuracy: 0.1489 - val_loss: 2.2749 - val_accuracy: 0.1468
# Epoch 6/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.2590 - accuracy: 0.1534 - val_loss: 2.2348 - val_accuracy: 0.1531
# Epoch 7/10
# 391/391 [==============================] - 4s 10ms/step - loss: 2.1994 - accuracy: 0.1664 - val_loss: 2.1680 - val_accuracy: 0.1659
# Epoch 8/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.1256 - accuracy: 0.1894 - val_loss: 2.1016 - val_accuracy: 0.1993
# Epoch 9/10
# 391/391 [==============================] - 4s 10ms/step - loss: 2.0737 - accuracy: 0.2197 - val_loss: 2.0559 - val_accuracy: 0.2331
# Epoch 10/10
# 391/391 [==============================] - 4s 11ms/step - loss: 2.0378 - accuracy: 0.2401 - val_loss: 2.0202 - val_accuracy: 0.2458

# %%
model_adagrad.save('model_adagrad.h5')

# %%
# Combined Training Accuracy Plot

plt.plot(history_sgd_plain.history['accuracy'])
plt.plot(history_adam.history['accuracy'])
plt.plot(history_rmsprop.history['accuracy'])

plt.plot(history_adagrad.history['accuracy'])

plt.title('Accuracies')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['SGD', 'Adam', 'RMSprop', 'Adadelta', 'Adagrad'])
plt.savefig('Combined-Accuracy.jpg', dpi=200)

# %%
# SGD
plt.plot(history_sgd_plain.history['accuracy'])
plt.plot(history_sgd_plain.history['val_accuracy'])
plt.title('SGD - Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.savefig('SGD-Accuracy.jpg')
plt.show()

print()

# %%
plt.plot(history_sgd_plain.history['loss'])
plt.plot(history_sgd_plain.history['val_loss'])
plt.title('SGD - Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.savefig('SGD-Loss.jpg')
plt.show()

# %%
# Adam
plt.plot(history_adam.history['accuracy'])
plt.plot(history_adam.history['val_accuracy'])
plt.title('Adam - Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.savefig('Adam-Accuracy.jpg')
plt.show()

print()
print()

plt.plot(history_adam.history['loss'])
plt.plot(history_adam.history['val_loss'])
plt.title('Adam - Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.savefig('Adam-Loss.jpg')
plt.show()

# %%
# RMSprop
plt.plot(history_rmsprop.history['accuracy'])
plt.plot(history_rmsprop.history['val_accuracy'])
plt.title('RMSprop - Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.savefig('RMSprop-Accuracy.jpg')
plt.show()

print()
print()

plt.plot(history_rmsprop.history['loss'])
plt.plot(history_rmsprop.history['val_loss'])
plt.title('RMSprop - Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.savefig('RMSprop-Loss.jpg')
plt.show()

# %%
# Adagrad
plt.plot(history_adagrad.history['accuracy'])
plt.plot(history_adagrad.history['val_accuracy'])
plt.title('Adagrad - Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.savefig('Adagrad-Accuracy.jpg')
plt.show()

print()
print()

plt.plot(history_adagrad.history['loss'])
plt.plot(history_adagrad.history['val_loss'])
plt.title('Adagrad - Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.savefig('Adagrad-Loss.jpg')
plt.show()
